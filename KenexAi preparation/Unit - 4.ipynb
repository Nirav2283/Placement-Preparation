# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(data=[1,2,3,5],index=np.arange(100,500,100))

# %%
s
# Out:
# 100    1
# 200    2
# 300    3
# 400    5
# dtype: int64

# %%
s[100] + s[200]
# Out:
# 3

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv("titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/by/8_8v2yf54c11829sxdn1r3400000gn/T/ipykernel_5733/1519666860.py in <module>
# ----> 1 df = pd.read_csv("titanic.csv")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
import numpy as np 
import pandas as pd 
dates = pd.to_datetime("13/08/2024")

i = dates + pd.to_timedelta(np.arange(10), unit='h') 

d = [50,53,25,70,60,50,53,25,70,60] 

time_series = pd.Series(data=d,index=i)

print(time_series)
# Out:
# 2024-08-13 00:00:00    50
# 2024-08-13 01:00:00    53
# 2024-08-13 02:00:00    25
# 2024-08-13 03:00:00    70
# 2024-08-13 04:00:00    60
# 2024-08-13 05:00:00    50
# 2024-08-13 06:00:00    53
# 2024-08-13 07:00:00    25
# 2024-08-13 08:00:00    70
# 2024-08-13 09:00:00    60
# dtype: int64
# /var/folders/by/8_8v2yf54c11829sxdn1r3400000gn/T/ipykernel_5733/4035685041.py:3: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   dates = pd.to_datetime("13/08/2024")

# %%
time_series.plot()
# Out:
# <AxesSubplot:>

# %%
data = np.random.randint(1,100,(5,4))
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
data
# Out:
# array([[94, 99, 19, 90],
#        [64, 46, 69, 35],
#        [88, 25, 34, 50],
#        [78, 49, 80,  6],
#        [99, 41,  5,  5]])

# %%
r = np.arange(101,106)
r
# Out:
# array([101, 102, 103, 104, 105])

# %%
c = ['PDS','IAT','.NET','PHP']

# %%
df = pd.DataFrame(data=data,index=r,columns=c)

# %%
df
# Out:
#      PDS  IAT  .NET  PHP
# 101   94   99    19   90
# 102   64   46    69   35
# 103   88   25    34   50
# 104   78   49    80    6
# 105   99   41     5    5

# %%
df['PDS']
# Out:
# 101    94
# 102    64
# 103    88
# 104    78
# 105    99
# Name: PDS, dtype: int64

# %%
df
# Out:
#      PDS  IAT  .NET  PHP
# 101   94   99    19   90
# 102   64   46    69   35
# 103   88   25    34   50
# 104   78   49    80    6
# 105   99   41     5    5

# %%
df.iloc[0]
# Out:
# PDS     94
# IAT     99
# .NET    19
# PHP     90
# Name: 101, dtype: int64

# %%
df[['PDS','IAT']].loc[[101,102]]
# Out:
#      PDS  IAT
# 101   94   99
# 102   64   46

# %%
df.loc[[101,102]][['PDS','IAT']]
# Out:
#      PDS  IAT
# 101   94   99
# 102   64   46

# %%
df['Total'] = df['PDS'] + df['IAT'] + df['.NET'] + df['PHP']

# %%
df.drop(101,inplace=True)

# %%
df
# Out:
#      PDS  IAT  .NET  PHP  Total
# 102   64   46    69   35    214
# 103   88   25    34   50    197
# 104   78   49    80    6    213
# 105   99   41     5    5    150

# %%
df[df >50]
# Out:
#      PDS  IAT  .NET  PHP  Total
# 102   64  NaN  69.0  NaN    214
# 103   88  NaN   NaN  NaN    197
# 104   78  NaN  80.0  NaN    213
# 105   99  NaN   NaN  NaN    150

# %%
a1 = np.arange(1,6)

# %%
a1[a1 % 2 == 0]
# Out:
# array([2, 4])

# %%
df[df['PDS'] == df['PDS'].max()]
# Out:
#      PDS  IAT  .NET  PHP  Total
# 105   99   41     5    5    150

# %%
df
# Out:
#      PDS  IAT  .NET  PHP  Total
# 102   64   46    69   35    214
# 103   88   25    34   50    197
# 104   78   49    80    6    213
# 105   99   41     5    5    150

# %%
df[df['PDS']>50]
# Out:
#      PDS  IAT  .NET  PHP  Total
# 102   64   46    69   35    214
# 103   88   25    34   50    197
# 104   78   49    80    6    213
# 105   99   41     5    5    150

# %%
df
# Out:
#      PDS  IAT  .NET  PHP
# 101   70   28    90   23
# 102   56   60    46   56
# 103   34   52    54   67
# 104   47   43    22   13
# 105   85   86    97   37

# %%
df = pd.read_csv("titanic.csv")

# %%
df.set_index("PassengerId",inplace=True)

# %%
df.reset_index()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.index.name = "RollNo"

# %%
df
# Out:
#         PDS  IAT  .NET  PHP
# RollNo
# 101      70   28    90   23
# 102      56   60    46   56
# 103      34   52    54   67
# 104      47   43    22   13
# 105      85   86    97   37

# %%
df.loc[101]
# Out:
# PDS     70
# IAT     28
# .NET    90
# PHP     23
# Name: 101, dtype: int64

# %%
df1 = pd.read_csv("multidataframe.csv",index_col=['Col','DEP','Sem','RN'])

# %%
df1.loc['ABC',]
# Out:
#                      S1  S2  S3
# Col     DEP Sem RN
# ABC     CE  5   101  50  60  70
#                 102  48  70  25
#             7   101  58  59  51
#         ME  5   101  30  35  39
#                 102  50  90  48
# Darshan CE  5   101  88  99  77
#                 102  99  84  76
#             7   101  88  77  99
#         ME  5   101  44  88  99

# %%
df1
# Out:
#                      S1  S2  S3
# Col     DEP Sem RN
# ABC     CE  5   101  50  60  70
#                 102  48  70  25
#             7   101  58  59  51
#         ME  5   101  30  35  39
#                 102  50  90  48
# Darshan CE  5   101  88  99  77
#                 102  99  84  76
#             7   101  88  77  99
#         ME  5   101  44  88  99

# %%
df1
# Out:
#                      S1  S2  S3
# Col     DEP Sem RN
# ABC     CE  5   101  50  60  70
#                 102  48  70  25
#             7   101  58  59  51
#         ME  5   101  30  35  39
#                 102  50  90  48
# Darshan CE  5   101  88  99  77
#                 102  99  84  76
#             7   101  88  77  99
#         ME  5   101  44  88  99

# %%
df1.xs(5,axis=0,level="Sem",drop_level=False)

# %%
df1.xs(5,axis=0,level="Sem",drop_level=False).xs('CE',axis=0,level="DEP",drop_level=False)
# Out:
#                      S1  S2  S3
# Col     DEP Sem RN
# ABC     CE  5   101  50  60  70
#                 102  48  70  25
# Darshan CE  5   101  88  99  77
#                 102  99  84  76

# %%
df2 =pd.read_csv("titanic.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df = pd.DataFrame([[np.nan, 2, np.nan, 0],[3, 4, np.nan, 1],
[np.nan, np.nan, np.nan, np.nan],[np.nan, 3, np.nan, 4]], columns=list("ABCD"))

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df.fillna(df['A'].min(),axis=1)
# Out:
#      A    B    C    D
# 0  3.0  2.0  3.0  0.0
# 1  3.0  4.0  3.0  1.0
# 2  3.0  3.0  3.0  3.0
# 3  3.0  3.0  3.0  4.0

# %%
df
# Out:
#      A    B   C    D
# 0  NaN  2.0 NaN  0.0
# 1  3.0  4.0 NaN  1.0
# 2  NaN  NaN NaN  NaN
# 3  NaN  3.0 NaN  4.0

# %%
df.interpolate(method='polynomial', limit_direction="both")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/30/3wcvnzrj19z45z0zlz3pvb7h0000gn/T/ipykernel_13428/4133150569.py in <module>
# ----> 1 df.interpolate(method='polynomial', limit_direction="both")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10938         **kwargs,
#   10939     ) -> DataFrame | None:
# > 10940         return super().interpolate(
#   10941             method,
#   10942             axis,
#
# ...

# %%
df = pd.read_csv("college.csv")

# %%
df
# Out:
#     College  Enno  CPI
# 0   Darshan   123  8.9
# 1   Darshan   124  9.2
# 2   Darshan   125  7.8
# 3   Darshan   128  8.7
# 4       ABC   211  5.6
# 5       ABC   212  6.2
# 6       ABC   215  3.2
# 7       ABC   218  4.2
# 8       XYZ   312  5.2
# 9       XYZ   315  6.5
# 10      XYZ   315  5.8

# %%
df.groupby(["College",'Enno']).groups
# Out:
# {('ABC', 211): [4], ('ABC', 212): [5], ('ABC', 215): [6], ('ABC', 218): [7], ('Darshan', 123): [0], ('Darshan', 124): [1], ('Darshan', 125): [2], ('Darshan', 128): [3], ('XYZ', 312): [8], ('XYZ', 315): [9, 10]}

# %%
for collegename,data in df.groupby(["College",'Enno']):
    print("---->",collegename,"<----")
    print(data['CPI'].mean())
# Out:
# ----> ('ABC', 211) <----
# 5.6
# ----> ('ABC', 212) <----
# 6.2
# ----> ('ABC', 215) <----
# 3.2
# ----> ('ABC', 218) <----
# 4.2
# ----> ('Darshan', 123) <----
# 8.9
# ----> ('Darshan', 124) <----
# 9.2
# ----> ('Darshan', 125) <----
# 7.8
# ----> ('Darshan', 128) <----
# 8.7
# ----> ('XYZ', 312) <----
# 5.2
# ----> ('XYZ', 315) <----
# 6.15

# %%
df1 = pd.read_csv('data1.csv')

# %%
df2 = pd.read_csv('data2.csv')

# %%
df1
# Out:
#     College  Enno  CPI
# 0   Darshan   123  8.9
# 1   Darshan   124  9.2
# 2   Darshan   125  7.8
# 3   Darshan   128  8.7
# 4       ABC   211  5.6
# 5       ABC   212  6.2
# 6       ABC   215  3.2
# 7       ABC   218  4.2
# 8       XYZ   312  5.2
# 9       XYZ   315  6.5
# 10      XYZ   315  5.8

# %%
pd.concat([df1,df2],axis=1)
# Out:
#     College  Enno  CPI  College  Enno  CPI
# 0   Darshan   123  8.9  Darshan   123  8.9
# 1   Darshan   124  9.2  Darshan   124  9.2
# 2   Darshan   125  7.8  Darshan   125  7.8
# 3   Darshan   128  8.7  Darshan   128  8.7
# 4       ABC   211  5.6      ABC   211  5.6
# 5       ABC   212  6.2      ABC   212  6.2
# 6       ABC   215  3.2      ABC   215  3.2
# 7       ABC   218  4.2      ABC   218  4.2
# 8       XYZ   312  5.2      XYZ   312  5.2
# 9       XYZ   315  6.5      XYZ   315  6.5
# 10      XYZ   315  5.8      XYZ   315  5.8

# %%
df1 = pd.read_csv('studentinfo.csv')

# %%
df2 = pd.read_csv('marks.csv')

# %%
df1
# Out:
#     rollno                               Name  Sem Branch
# 0      101  Baraiya Nikhilkumar Rajnikantbhai    3    MCA
# 1      102               Bhatt Jay Girishbhai    3    MCA
# 2      103           Bhindi Prince Sanjaybhai    3    MCA
# 3      104           Chitroda Smit Sureshbhai    3    MCA
# 4      105     Chothani Anirudhdha Arvindbhai    3    MCA
# 5      106        Dalasaniya Riken Ashvinbhai    3    MCA
# 6      107          Dholakiya Meet Rajeshbhai    3    MCA
# 7      108            Dodiya Mohit Nitinkumar    3    MCA
# 8      109         Jobanputra Amee Prafulbhai    3    MCA
# 9      110            Kadivar Sahinbanu Ikbal    3    MCA
# 10     111           Kadivar Tasnimbanu Yasin    3    MCA

# %%
df2
# Out:
#    rollno  iat  pds  php
# 0     101   30   40   59
# 1     105   40   40   30
# 2     106   50   80   90
# 3     102   60  100   30
# 4     107   70  110   40
# 5     104   80  120   50
# 6     103   90  130   60
# 7     111  100   40   70
# 8     110  110   80   59
# 9     109  120  100   30

# %%
df1.merge(df2,on='rollno')
# Out:
#    rollno                               Name  Sem Branch  iat  pds  php
# 0     101  Baraiya Nikhilkumar Rajnikantbhai    3    MCA   30   40   59
# 1     102               Bhatt Jay Girishbhai    3    MCA   60  100   30
# 2     103           Bhindi Prince Sanjaybhai    3    MCA   90  130   60
# 3     104           Chitroda Smit Sureshbhai    3    MCA   80  120   50
# 4     105     Chothani Anirudhdha Arvindbhai    3    MCA   40   40   30
# 5     106        Dalasaniya Riken Ashvinbhai    3    MCA   50   80   90
# 6     107          Dholakiya Meet Rajeshbhai    3    MCA   70  110   40
# 7     109         Jobanputra Amee Prafulbhai    3    MCA  120  100   30
# 8     110            Kadivar Sahinbanu Ikbal    3    MCA  110   80   59
# 9     111           Kadivar Tasnimbanu Yasin    3    MCA  100   40   70

# %%
pd.read_excel("studentData.xlsx")
# Out:
#     Enrollment No  RollNo                      StudentLCName DivisionCode  \
# 0      24UG010201     501                   DIKSHITA KOTHARI       CSE-3C
# 1      24UG010196     502               LO KHUSHBOO AMRUTLAL       CSE-3C
# 2      24UG010187     503                IDA GAURAV RAJUBHAI       CSE-3C
# 3      24UG010202     504       GOHIL ARJUNSINH NARENDRASINH       CSE-3C
# 4      24UG010256     505         SHEKHAT TEJASVI BHARATBHAI       CSE-3C
# ..            ...     ...                                ...          ...
# 446   23010101430     454  Sherasiya Gulamkasim Mohamadhanif       CSE-3B
# 447   23010101431     357          Sorathiya Raj Kamleshbhai       CSE-3B
# 448   23010101432     416       Trambadiya Priyal Hareshbhai       CSE-3B
# 449   23010101433     358     Zala Jayvardhansinh Pratapsinh       CSE-3B
# 450   23010101434     473           Zalariya Parth Dipakbhai       CSE-3B
#
#      LabBatchNo  Gender
# 0             1  Female
# 1             1  Female
# ...
